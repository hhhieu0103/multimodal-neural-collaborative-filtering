# %%
import pandas as pd

# %%
df_metadata = pd.read_csv('performance/metadata-feature-metrics.csv')
df_metadata
# Out:
#             metadata_feature  hit_ratio      ndcg    recall
# 0    mm_total_recommendation   0.002761  0.001091  0.002699
# 1     z_total_recommendation   0.001228  0.000557  0.001171
# 2   log_total_recommendation   0.009730  0.004598  0.009381
# 3                   mm_price   0.001419  0.000518  0.001363
# 4                    z_price   0.000152  0.000048  0.000141
# 5                  log_price   0.000590  0.000210  0.000568
# 6               lang_encoded   0.000048  0.000015  0.000043
# 7                cat_encoded   0.001714  0.000717  0.001649
# 8                gen_encoded   0.002418  0.001009  0.002339
# 9                 developers   0.000476  0.000174  0.000451
# 10                publishers   0.000714  0.000348  0.000655
# 11          mm_released_date   0.000029  0.000011  0.000029
# 12           z_released_date   0.000048  0.000018  0.000043
# 13         log_released_date   0.000209  0.000079  0.000205
# 14                    mm_age   0.000314  0.000100  0.000309
# ...

# %%
df_time = pd.read_csv('performance/time-feature-metrics.csv')
df_time
# Out:
#    Unnamed: 0                         time_feature  hit_ratio@10   ndcg@10  \
# 0           0                         mm_timestamp      0.000094  0.000037
# 1           1                          z_timestamp      0.000134  0.000046
# 2           2                        log_timestamp      0.000128  0.000039
# 3           3       relative_most_recent_timestamp      0.000094  0.000034
# 4           4           relative_current_timestamp      0.000087  0.000038
# 5           5  relative_last_interaction_timestamp      0.000101  0.000038
#
#    recall@10
# 0   0.000094
# 1   0.000113
# 2   0.000100
# 3   0.000086
# 4   0.000084
# 5   0.000097

# %%
df_baseline = pd.read_csv('performance/baseline-performance.csv')
df_baseline
# Out:
#     factors             layers  learning_rate  epochs  batch_size optimizer  \
# 0        64  [128, 64, 32, 16]         0.0010      50        8192   adagrad
# 1        16  [128, 64, 32, 16]         0.0001      20        4096      adam
# 2        32  [128, 64, 32, 16]         0.0010      50        4096       sgd
# 3        32  [128, 64, 32, 16]         0.0100      50        8192      adam
# 4        64    [64, 32, 16, 8]         0.0001      10       16384       sgd
# 5        64    [64, 32, 16, 8]         0.0010      20        8192       sgd
# 6        16    [64, 32, 16, 8]         0.0001      50        8192   adagrad
# 7        64    [64, 32, 16, 8]         0.0001      10       16384       sgd
# 8        32  [128, 64, 32, 16]         0.0001      50       16384      adam
# 9        64  [128, 64, 32, 16]         0.0100      50       16384      adam
# 10       64  [128, 64, 32, 16]         0.0010      50        4096   adagrad
# ...
