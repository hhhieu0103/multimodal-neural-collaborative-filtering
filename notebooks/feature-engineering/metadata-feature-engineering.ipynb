# %%
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv('../../data/metadata-clean.csv')
df.head()
# Out:
#                              name  item_id  \
# 0               Clash of Warlords  1430720
# 1  Mine Crazy: The Korean Grinder  1430740
# 2                            Fade  1430100
# 3       Clash: Artifacts of Chaos  1430680
# 4                         Astatos  1430970
#
#                                  supported_languages  \
# 0      ['Simplified Chinese', 'Traditional Chinese']
# 1                                        ['English']
# 2                                        ['English']
# 3  ['English', 'French', 'Italian', 'German', 'Sp...
# 4  ['English', 'Simplified Chinese', 'Traditional...
#
#                       developers           publishers  \
# 0              ['XINLINE GAMES']    ['XINLINE GAMES']
# 1                  ['Dano Sato']    ['RealMono Inc.']
# 2            ['Azimyth Studios']  ['Azimyth Studios']
# 3                   ['ACE Team']            ['Nacon']
# 4  ['Studio Klondike Australia']  ['Studio Klondike']
#
#                                           categories  \
# 0  ['Single-player', 'In-App Purchases', 'Family ...
# 1                ['Single-player', 'Family Sharing']
# 2                ['Single-player', 'Family Sharing']
# 3  ['Single-player', 'Steam Achievements', 'Steam...
# 4  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                               genres  total_recommendations  \
# 0                                       ['Strategy']                      0
# 1           ['Casual', 'Indie', 'RPG', 'Simulation']                      0
# 2                                   ['Indie', 'RPG']                      0
# 3                   ['Action', 'Adventure', 'Indie']                    759
# 4  ['Adventure', 'Indie', 'Strategy', 'Early Acce...                    243
#
#   released_date                                               tags   price
# 0    2021-02-07  ['Turn-Based Tactics', 'Strategy', 'Wargame', ...   699.0
# 1    2020-10-08  ['Casual', 'RPG', 'Simulation', 'Clicker', 'Fa...   199.0
# 2    2020-10-29  ['Horror', 'RPG', 'Survival Horror', 'Top-Down...   199.0
# 3    2023-03-09  ['Action', 'Adventure', 'RPG', 'Souls-like', '...  2999.0
# 4    2021-12-16  ['Early Access', 'Visual Novel', 'Card Battler...  1499.0

# %% [markdown]
# ## Numerical feature encoding

# %%
def min_max(values: pd.Series):
    min_time = values.min()
    max_time = values.max()
    normalized = (values - min_time) / (max_time - min_time)
    return normalized

def z_score(values: pd.Series):
    mean_time = values.mean()
    std_time = values.std()
    standardized = (values - mean_time) / std_time
    return standardized

def log_normalize(values: pd.Series):
    min_time = values.min()
    offset_timestamps = values - min_time
    epsilon = 1e-10
    return np.log(offset_timestamps + epsilon)

# %% [markdown]
# ### Total recommendation

# %%
df['mm_total_recommendation'] = min_max(df['total_recommendations'])
df['z_total_recommendation'] = z_score(df['total_recommendations'])
df['log_total_recommendation'] = log_normalize(df['total_recommendations'])

df.head()
# Out:
#                              name  item_id  \
# 0               Clash of Warlords  1430720
# 1  Mine Crazy: The Korean Grinder  1430740
# 2                            Fade  1430100
# 3       Clash: Artifacts of Chaos  1430680
# 4                         Astatos  1430970
#
#                                  supported_languages  \
# 0      ['Simplified Chinese', 'Traditional Chinese']
# 1                                        ['English']
# 2                                        ['English']
# 3  ['English', 'French', 'Italian', 'German', 'Sp...
# 4  ['English', 'Simplified Chinese', 'Traditional...
#
#                       developers           publishers  \
# 0              ['XINLINE GAMES']    ['XINLINE GAMES']
# 1                  ['Dano Sato']    ['RealMono Inc.']
# 2            ['Azimyth Studios']  ['Azimyth Studios']
# 3                   ['ACE Team']            ['Nacon']
# 4  ['Studio Klondike Australia']  ['Studio Klondike']
#
#                                           categories  \
# 0  ['Single-player', 'In-App Purchases', 'Family ...
# 1                ['Single-player', 'Family Sharing']
# 2                ['Single-player', 'Family Sharing']
# 3  ['Single-player', 'Steam Achievements', 'Steam...
# 4  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                               genres  total_recommendations  \
# 0                                       ['Strategy']                      0
# 1           ['Casual', 'Indie', 'RPG', 'Simulation']                      0
# 2                                   ['Indie', 'RPG']                      0
# 3                   ['Action', 'Adventure', 'Indie']                    759
# 4  ['Adventure', 'Indie', 'Strategy', 'Early Acce...                    243
#
#   released_date                                               tags   price  \
# 0    2021-02-07  ['Turn-Based Tactics', 'Strategy', 'Wargame', ...   699.0
# 1    2020-10-08  ['Casual', 'RPG', 'Simulation', 'Clicker', 'Fa...   199.0
# 2    2020-10-29  ['Horror', 'RPG', 'Survival Horror', 'Top-Down...   199.0
# 3    2023-03-09  ['Action', 'Adventure', 'RPG', 'Souls-like', '...  2999.0
# 4    2021-12-16  ['Early Access', 'Visual Novel', 'Card Battler...  1499.0
#
#    mm_total_recommendation  z_total_recommendation  log_total_recommendation
# 0                 0.000000               -0.046711                -23.025851
# 1                 0.000000               -0.046711                -23.025851
# 2                 0.000000               -0.046711                -23.025851
# 3                 0.000174               -0.011641                  6.632002
# 4                 0.000056               -0.035483                  5.493061

# %% [markdown]
# ### Price

# %%
df['mm_price'] = min_max(df['price'])
df['z_price'] = z_score(df['price'])
df['log_price'] = log_normalize(df['price'])

df.head()
# Out:
#                              name  item_id  \
# 0               Clash of Warlords  1430720
# 1  Mine Crazy: The Korean Grinder  1430740
# 2                            Fade  1430100
# 3       Clash: Artifacts of Chaos  1430680
# 4                         Astatos  1430970
#
#                                  supported_languages  \
# 0      ['Simplified Chinese', 'Traditional Chinese']
# 1                                        ['English']
# 2                                        ['English']
# 3  ['English', 'French', 'Italian', 'German', 'Sp...
# 4  ['English', 'Simplified Chinese', 'Traditional...
#
#                       developers           publishers  \
# 0              ['XINLINE GAMES']    ['XINLINE GAMES']
# 1                  ['Dano Sato']    ['RealMono Inc.']
# 2            ['Azimyth Studios']  ['Azimyth Studios']
# 3                   ['ACE Team']            ['Nacon']
# 4  ['Studio Klondike Australia']  ['Studio Klondike']
#
#                                           categories  \
# 0  ['Single-player', 'In-App Purchases', 'Family ...
# 1                ['Single-player', 'Family Sharing']
# 2                ['Single-player', 'Family Sharing']
# 3  ['Single-player', 'Steam Achievements', 'Steam...
# 4  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                               genres  total_recommendations  \
# 0                                       ['Strategy']                      0
# 1           ['Casual', 'Indie', 'RPG', 'Simulation']                      0
# 2                                   ['Indie', 'RPG']                      0
# 3                   ['Action', 'Adventure', 'Indie']                    759
# 4  ['Adventure', 'Indie', 'Strategy', 'Early Acce...                    243
#
#   released_date                                               tags   price  \
# 0    2021-02-07  ['Turn-Based Tactics', 'Strategy', 'Wargame', ...   699.0
# 1    2020-10-08  ['Casual', 'RPG', 'Simulation', 'Clicker', 'Fa...   199.0
# 2    2020-10-29  ['Horror', 'RPG', 'Survival Horror', 'Top-Down...   199.0
# 3    2023-03-09  ['Action', 'Adventure', 'RPG', 'Souls-like', '...  2999.0
# 4    2021-12-16  ['Early Access', 'Visual Novel', 'Card Battler...  1499.0
#
#    mm_total_recommendation  z_total_recommendation  log_total_recommendation  \
# 0                 0.000000               -0.046711                -23.025851
# 1                 0.000000               -0.046711                -23.025851
# 2                 0.000000               -0.046711                -23.025851
# 3                 0.000174               -0.011641                  6.632002
# 4                 0.000056               -0.035483                  5.493061
#
#    mm_price   z_price  log_price
# 0  0.003679 -0.049534   6.549651
# 1  0.001047 -0.390004   5.293305
# 2  0.001047 -0.390004   5.293305
# 3  0.015784  1.516628   8.006034
# 4  0.007889  0.495218   7.312553

# %% [markdown]
# ## Date features encoding

# %%
df['released_date'] = pd.to_datetime(df['released_date'])
df['released_timestamp'] = df['released_date'].apply(lambda x: x.timestamp())

# %%
df['mm_released_date'] = min_max(df['released_timestamp'])
df['z_released_date'] = z_score(df['released_timestamp'])
df['log_released_date'] = log_normalize(df['released_timestamp'])

df.head()
# Out:
#                              name  item_id  \
# 0               Clash of Warlords  1430720
# 1  Mine Crazy: The Korean Grinder  1430740
# 2                            Fade  1430100
# 3       Clash: Artifacts of Chaos  1430680
# 4                         Astatos  1430970
#
#                                  supported_languages  \
# 0      ['Simplified Chinese', 'Traditional Chinese']
# 1                                        ['English']
# 2                                        ['English']
# 3  ['English', 'French', 'Italian', 'German', 'Sp...
# 4  ['English', 'Simplified Chinese', 'Traditional...
#
#                       developers           publishers  \
# 0              ['XINLINE GAMES']    ['XINLINE GAMES']
# 1                  ['Dano Sato']    ['RealMono Inc.']
# 2            ['Azimyth Studios']  ['Azimyth Studios']
# 3                   ['ACE Team']            ['Nacon']
# 4  ['Studio Klondike Australia']  ['Studio Klondike']
#
#                                           categories  \
# 0  ['Single-player', 'In-App Purchases', 'Family ...
# 1                ['Single-player', 'Family Sharing']
# 2                ['Single-player', 'Family Sharing']
# 3  ['Single-player', 'Steam Achievements', 'Steam...
# 4  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                               genres  total_recommendations  \
# 0                                       ['Strategy']                      0
# 1           ['Casual', 'Indie', 'RPG', 'Simulation']                      0
# 2                                   ['Indie', 'RPG']                      0
# 3                   ['Action', 'Adventure', 'Indie']                    759
# 4  ['Adventure', 'Indie', 'Strategy', 'Early Acce...                    243
#
#   released_date                                               tags  ...  \
# 0    2021-02-07  ['Turn-Based Tactics', 'Strategy', 'Wargame', ...  ...
# 1    2020-10-08  ['Casual', 'RPG', 'Simulation', 'Clicker', 'Fa...  ...
# 2    2020-10-29  ['Horror', 'RPG', 'Survival Horror', 'Top-Down...  ...
# 3    2023-03-09  ['Action', 'Adventure', 'RPG', 'Souls-like', '...  ...
# 4    2021-12-16  ['Early Access', 'Visual Novel', 'Card Battler...  ...
#
#    mm_total_recommendation  z_total_recommendation  log_total_recommendation  \
# 0                 0.000000               -0.046711                -23.025851
# 1                 0.000000               -0.046711                -23.025851
# 2                 0.000000               -0.046711                -23.025851
# 3                 0.000174               -0.011641                  6.632002
# 4                 0.000056               -0.035483                  5.493061
#
#    mm_price   z_price  log_price  released_timestamp  mm_released_date  \
# 0  0.003679 -0.049534   6.549651        1.612656e+09          0.855371
# 1  0.001047 -0.390004   5.293305        1.602115e+09          0.843270
# 2  0.001047 -0.390004   5.293305        1.603930e+09          0.845353
# 3  0.015784  1.516628   8.006034        1.678320e+09          0.930761
# 4  0.007889  0.495218   7.312553        1.639613e+09          0.886321
#
#    z_released_date  log_released_date
# 0         0.003497          20.428931
# 1        -0.103532          20.414682
# 2        -0.085109          20.417149
# 3         0.670236          20.513398
# 4         0.277211          20.464474
#
# [5 rows x 21 columns]

# %%
# df['released_year'] = df['released_date'].dt.year.astype('category')
# df.head()

# %%
# df['released_decade'] = (df['released_date'].dt.year // 10 * 10).astype('category')
# df.head()

# %%
# df['released_year'] = df['released_date'].dt.year.astype('category')
# df['released_month'] = df['released_date'].dt.month.astype('category')
# df['released_day_of_week'] = df['released_date'].dt.dayofweek.astype('category')
# df['released_quarter'] = df['released_date'].dt.quarter.astype('category')
# df.head()

# %%
# df_interactions = pd.read_csv('data/review-clean.csv')
# df_interactions.head()

# %%
# max_timestamp = df_interactions['timestamp'].max() # Latest date in the interaction data
# reference_date = pd.to_datetime(max_timestamp, unit='s')
# reference_date

# %%
# df['age'] = (reference_date - pd.to_datetime(df['released_date'])).dt.days.clip(lower=0) // 365.25
# df.head()

# %%
# age_buckets = ['new_release', 'recent', 'established', 'classic']
# df['age_category'] = pd.cut(
#     df['age'],
#     bins=[0, 1, 3, 10, float('inf')],
#     labels=age_buckets
# ).astype('category')
# df.head()

# %%
# df['mm_age'] = min_max(df['age'])
# df['z_age'] = z_score(df['age'])
# df['log_age'] = log_normalize(df['age'])
#
# df.head()

# %% [markdown]
# ## Categorical feature encoding

# %%
df['publishers'] = df['publishers'].apply(ast.literal_eval)
df['developers'] = df['developers'].apply(ast.literal_eval)
df['tags'] = df['tags'].apply(ast.literal_eval)
df['supported_languages'] = df['supported_languages'].apply(ast.literal_eval)
df['genres'] = df['genres'].apply(ast.literal_eval)
df['categories'] = df['categories'].apply(ast.literal_eval)

# %%
unique_publishers = df['publishers'].explode().unique()
unique_developers = df['developers'].explode().unique()
unique_tags = df['tags'].explode().unique()
unique_supported_languages = df['supported_languages'].explode().unique()
unique_genres = df['genres'].explode().unique()
unique_categories = df['categories'].explode().unique()

# %%
publishers_mapper = {publisher: i for i, publisher in enumerate(unique_publishers)}
developers_mapper = {developer: i for i, developer in enumerate(unique_developers)}
tags_mapper = {tag: i for i, tag in enumerate(unique_tags)}
languages_mapper = {language: i for i, language in enumerate(unique_supported_languages)}
genres_mapper = {genre: i for i, genre in enumerate(unique_genres)}
categories_mapper = {category: i for i, category in enumerate(unique_categories)}

# %%
df['publishers'] = df['publishers'].apply(lambda x: [publishers_mapper[pub] for pub in x])
df['developers'] = df['developers'].apply(lambda x: [developers_mapper[dev] for dev in x])
df['tags'] = df['tags'].apply(lambda x: [tags_mapper[tag] for tag in x])
df['supported_languages'] = df['supported_languages'].apply(lambda x: [languages_mapper[lang] for lang in x])
df['genres'] = df['genres'].apply(lambda x: [genres_mapper[gen] for gen in x])
df['categories'] = df['categories'].apply(lambda x: [categories_mapper[cat] for cat in x])

# %% [markdown]
# # Merge to interaction

# %%
df_interactions = pd.read_csv('../../data/interaction-clean.csv')
df_interactions.head()
# Out:
#              user_id                                             review  \
# 0  76561197960432447  A legendary tactical shooter that shaped the g...
# 1  76561198071230926  The best CS sure, but server browser is the il...
# 2  76561198206216352  Some of the best memories of my childhood were...
# 3  76561198110801124  This game feels so much better than CS2. I kno...
# 4  76561199813732773  its very fun to play you can make friends out ...
#
#     timestamp  rating  item_id  rating_exp  rating_imp  mm_timestamp  \
# 0  1738278781    True       10           1           1      0.998997
# 1  1736206418    True       10           1           1      0.994407
# 2  1738041574    True       10           1           1      0.998472
# 3  1738015332    True       10           1           1      0.998414
# 4  1737853720    True       10           1           1      0.998056
#
#    z_timestamp  log_timestamp
# 0     0.559647      19.927005
# 1     0.535447      19.922399
# 2     0.556877      19.926479
# 3     0.556570      19.926420
# 4     0.554683      19.926062

# %%
items_in_interaction = df_interactions['item_id'].unique()
items_in_metadata = df['item_id'].unique()

# %%
items_missing_metadata = set(items_in_interaction) - set(items_in_metadata)
len(items_missing_metadata)
# Out:
# 605

# %%
df_merged = pd.merge(df_interactions, df, on='item_id', how='left')
df_merged.head()
# Out:
#              user_id                                             review  \
# 0  76561197960432447  A legendary tactical shooter that shaped the g...
# 1  76561198071230926  The best CS sure, but server browser is the il...
# 2  76561198206216352  Some of the best memories of my childhood were...
# 3  76561198110801124  This game feels so much better than CS2. I kno...
# 4  76561199813732773  its very fun to play you can make friends out ...
#
#     timestamp  rating  item_id  rating_exp  rating_imp  mm_timestamp  \
# 0  1738278781    True       10           1           1      0.998997
# 1  1736206418    True       10           1           1      0.994407
# 2  1738041574    True       10           1           1      0.998472
# 3  1738015332    True       10           1           1      0.998414
# 4  1737853720    True       10           1           1      0.998056
#
#    z_timestamp  log_timestamp  ... mm_total_recommendation  \
# 0     0.559647      19.927005  ...                0.036216
# 1     0.535447      19.922399  ...                0.036216
# 2     0.556877      19.926479  ...                0.036216
# 3     0.556570      19.926420  ...                0.036216
# 4     0.554683      19.926062  ...                0.036216
#
#   z_total_recommendation log_total_recommendation  mm_price   z_price  \
# 0               7.233859                11.967625  0.005258  0.154748
# 1               7.233859                11.967625  0.005258  0.154748
# 2               7.233859                11.967625  0.005258  0.154748
# 3               7.233859                11.967625  0.005258  0.154748
# 4               7.233859                11.967625  0.005258  0.154748
#
#   log_price  released_timestamp mm_released_date z_released_date  \
# 0  6.906755         973036800.0          0.12102       -6.491067
# 1  6.906755         973036800.0          0.12102       -6.491067
# 2  6.906755         973036800.0          0.12102       -6.491067
# 3  6.906755         973036800.0          0.12102       -6.491067
# 4  6.906755         973036800.0          0.12102       -6.491067
#
#    log_released_date
# 0          18.473349
# 1          18.473349
# 2          18.473349
# 3          18.473349
# 4          18.473349
#
# [5 rows x 30 columns]

# %%
df_merged[df_merged['tags'].isna()]
# Out:
#                    user_id                                             review  \
# 1747     76561197993732805  If it were free, I would recommend it, but it ...
# 1748     76561197961366898  As you can see I've played this game a lot.  U...
# 1749     76561197994829189  Pro: \nGood program for beginers and industry ...
# 1750     76561198021622527  I bought this software ages ago... loved it wh...
# 1751     76561198057822506  I bought Silo back when it was only $80 and du...
# ...                    ...                                                ...
# 1154304  76561198335465482  I still can't believe this exists. It is liter...
# 1154305  76561198061225363  A very effective solution, it can get a 30fps ...
# 1154306  76561198174393245  If you are a fan of classic games and tired of...
# 1154318  76561199755184852                                     Road work now!
# 1154319  76561198884562578  After spending 3 hours with Bob's Track Builde...
#
#           timestamp  rating  item_id  rating_exp  rating_imp  mm_timestamp  \
# 1747     1418663157   False   100400          -1           0      0.291045
# 1748     1520573235    True   100400           1           1      0.516777
# 1749     1405428735    True   100400           1           1      0.261730
# 1750     1634774536   False   100400          -1           0      0.769734
# 1751     1564964168   False   100400          -1           0      0.615103
# ...             ...     ...      ...         ...         ...           ...
# 1154304  1731332290    True   993090           1           1      0.983611
# 1154305  1731414171    True   993090           1           1      0.983792
# 1154306  1735834831    True   993090           1           1      0.993584
# 1154318  1736961983    True   993270           1           1      0.996080
# 1154319  1734131546    True   993270           1           1      0.989811
#
#          z_timestamp  log_timestamp  ... mm_total_recommendation  \
# 1747       -3.172575      18.693730  ...                     NaN
# 1748       -1.982549      19.267864  ...                     NaN
# 1749       -3.327117      18.587567  ...                     NaN
# 1750       -0.648995      19.666298  ...                     NaN
# 1751       -1.464186      19.442043  ...                     NaN
# ...              ...            ...  ...                     ...
# 1154304     0.478531      19.911483  ...                     NaN
# 1154305     0.479487      19.911667  ...                     NaN
# 1154306     0.531108      19.921571  ...                     NaN
# 1154318     0.544270      19.924081  ...                     NaN
# 1154319     0.511219      19.917767  ...                     NaN
#
#         z_total_recommendation log_total_recommendation mm_price z_price  \
# 1747                       NaN                      NaN      NaN     NaN
# 1748                       NaN                      NaN      NaN     NaN
# 1749                       NaN                      NaN      NaN     NaN
# 1750                       NaN                      NaN      NaN     NaN
# 1751                       NaN                      NaN      NaN     NaN
# ...                        ...                      ...      ...     ...
# 1154304                    NaN                      NaN      NaN     NaN
# 1154305                    NaN                      NaN      NaN     NaN
# 1154306                    NaN                      NaN      NaN     NaN
# 1154318                    NaN                      NaN      NaN     NaN
# 1154319                    NaN                      NaN      NaN     NaN
#
#         log_price  released_timestamp mm_released_date z_released_date  \
# 1747          NaN                 NaN              NaN             NaN
# 1748          NaN                 NaN              NaN             NaN
# 1749          NaN                 NaN              NaN             NaN
# 1750          NaN                 NaN              NaN             NaN
# 1751          NaN                 NaN              NaN             NaN
# ...           ...                 ...              ...             ...
# 1154304       NaN                 NaN              NaN             NaN
# 1154305       NaN                 NaN              NaN             NaN
# 1154306       NaN                 NaN              NaN             NaN
# 1154318       NaN                 NaN              NaN             NaN
# 1154319       NaN                 NaN              NaN             NaN
#
#          log_released_date
# 1747                   NaN
# 1748                   NaN
# 1749                   NaN
# 1750                   NaN
# 1751                   NaN
# ...                    ...
# 1154304                NaN
# 1154305                NaN
# 1154306                NaN
# 1154318                NaN
# 1154319                NaN
#
# [6271 rows x 30 columns]

# %%
df_merged.dropna(subset=['name'], inplace=True)
len(df_merged)
# Out:
# 1149955

# %% [markdown]
# ## Save file

# %%
df_merged
# Out:
#                    user_id                                             review  \
# 0        76561197960432447  A legendary tactical shooter that shaped the g...
# 1        76561198071230926  The best CS sure, but server browser is the il...
# 2        76561198206216352  Some of the best memories of my childhood were...
# 3        76561198110801124  This game feels so much better than CS2. I kno...
# 4        76561199813732773  its very fun to play you can make friends out ...
# ...                    ...                                                ...
# 1156221  76561198047845894  A fun and innovative game, not a bad thing to ...
# 1156222  76561198314652319  Developer, please listen to me, I love the con...
# 1156223  76561198035100973  Disclaimer: My scores/reviews are almost alway...
# 1156224  76561198414383514  Mediocre game with a pathetically bad challeng...
# 1156225  76561197992216244                                            Pogood.
#
#           timestamp  rating  item_id  rating_exp  rating_imp  mm_timestamp  \
# 0        1738278781    True       10           1           1      0.998997
# 1        1736206418    True       10           1           1      0.994407
# 2        1738041574    True       10           1           1      0.998472
# 3        1738015332    True       10           1           1      0.998414
# 4        1737853720    True       10           1           1      0.998056
# ...             ...     ...      ...         ...         ...           ...
# 1156221  1663545142    True   999890           1           1      0.833461
# 1156222  1689826252    True   999890           1           1      0.891674
# 1156223  1595699739    True   999990           1           1      0.683183
# 1156224  1706470035   False   999990          -1           0      0.928540
# 1156225  1720163517    True   999990           1           1      0.958872
#
#          z_timestamp  log_timestamp  ... mm_total_recommendation  \
# 0           0.559647      19.927005  ...                0.036216
# 1           0.535447      19.922399  ...                0.036216
# 2           0.556877      19.926479  ...                0.036216
# 3           0.556570      19.926420  ...                0.036216
# 4           0.554683      19.926062  ...                0.036216
# ...              ...            ...  ...                     ...
# 1156221    -0.313034      19.745840  ...                0.000000
# 1156222    -0.006144      19.813354  ...                0.000000
# 1156223    -1.105280      19.547015  ...                0.000000
# 1156224     0.188209      19.853867  ...                0.000000
# 1156225     0.348111      19.886010  ...                0.000000
#
#         z_total_recommendation log_total_recommendation  mm_price   z_price  \
# 0                     7.233859                11.967625  0.005258  0.154748
# 1                     7.233859                11.967625  0.005258  0.154748
# 2                     7.233859                11.967625  0.005258  0.154748
# 3                     7.233859                11.967625  0.005258  0.154748
# 4                     7.233859                11.967625  0.005258  0.154748
# ...                        ...                      ...       ...       ...
# 1156221              -0.046711               -23.025851  0.001574 -0.321910
# 1156222              -0.046711               -23.025851  0.001574 -0.321910
# 1156223              -0.046711               -23.025851  0.002626 -0.185722
# 1156224              -0.046711               -23.025851  0.002626 -0.185722
# 1156225              -0.046711               -23.025851  0.002626 -0.185722
#
#         log_price  released_timestamp mm_released_date z_released_date  \
# 0        6.906755        9.730368e+08         0.121020       -6.491067
# 1        6.906755        9.730368e+08         0.121020       -6.491067
# 2        6.906755        9.730368e+08         0.121020       -6.491067
# 3        6.906755        9.730368e+08         0.121020       -6.491067
# 4        6.906755        9.730368e+08         0.121020       -6.491067
# ...           ...                 ...              ...             ...
# 1156221  5.700444        1.554941e+09         0.789108       -0.582531
# 1156222  5.700444        1.554941e+09         0.789108       -0.582531
# 1156223  6.212606        1.567296e+09         0.803293       -0.457079
# 1156224  6.212606        1.567296e+09         0.803293       -0.457079
# 1156225  6.212606        1.567296e+09         0.803293       -0.457079
#
#          log_released_date
# 0                18.473349
# 1                18.473349
# 2                18.473349
# 3                18.473349
# 4                18.473349
# ...                    ...
# 1156221          20.348299
# 1156222          20.348299
# 1156223          20.366115
# 1156224          20.366115
# 1156225          20.366115
#
# [1149955 rows x 30 columns]

# %%
df_merged.to_csv('../../data/interaction-metadata.csv', index=False)

# %%
df.to_csv('../../data/metadata-features.csv', index=False)
