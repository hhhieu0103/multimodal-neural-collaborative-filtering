# %% [markdown]
# # Import libraries

# %%
import pandas as pd
from torch.utils.data import DataLoader
from dataset import NCFDataset
from recom_ncf import NCFRecommender
from evaluation import Evaluation
from helpers.index_manager import IndexManager
from helpers.dataloader_custom_functions import collate_fn, worker_init_fn
from helpers.cache import CacheType
from helpers.mem_map_dataloader import MemMapDataLoader
from ncf import ModelType

# %% [markdown]
# # Loading data

# %%
df_train = pd.read_csv('../data/train-leave2.csv')
df_val = pd.read_csv('../data/val-leave2.csv')
df_test = pd.read_csv('../data/test-leave2.csv')
index_manager = IndexManager()
index_manager.load('../data/index.pkl')

# %% [markdown]
# # Creating datasets

# %%
audio_dataloader = MemMapDataLoader(file_dir='D:/audio-features/mean', index_manager=index_manager, cache_type=CacheType.UNLIMITED, embed_dim=128)

# %%
train_dataset = NCFDataset(df_train, audio_dataloader=audio_dataloader)
val_dataset = NCFDataset(df_val, audio_dataloader=audio_dataloader)

dataloader_params = {
    'batch_size': 4096,
    'num_workers': 6,
    'persistent_workers': True,
    'prefetch_factor': 4,
    'pin_memory': True,
    'pin_memory_device': 'cuda',
    'collate_fn': collate_fn,
    'worker_init_fn': worker_init_fn,
}

train_dataloader = DataLoader(train_dataset, shuffle=True, **dataloader_params)
eval_dataloader = DataLoader(val_dataset, shuffle=False, **dataloader_params)

# %% [markdown]
# # Training model

# %%
params =  {'factors': 64, 'mlp_user_item_dim': 128, 'learning_rate': 0.0005, 'epochs': 50, 'optimizer': 'adagrad', 'dropout': 0.5, 'weight_decay': 0.0005, 'loss_fn': 'bce', 'audio_dim': 64}

unique_users = index_manager.get_indexed_values('user_id')
unique_items = index_manager.get_indexed_values('item_id')

model = NCFRecommender(unique_users, unique_items, audio_dataloader=audio_dataloader, model_type=ModelType.LATE_FUSION, **params)
model.fit(train_dataloader, eval_dataloader)
# Out:
# Epoch 1/50
# Train loss: 0.623665, Validation loss: 0.646860
# ==================================================
# Epoch 2/50
# Train loss: 0.595719, Validation loss: 0.642087
# ==================================================
# Epoch 3/50
# Train loss: 0.575809, Validation loss: 0.634271
# ==================================================
# Epoch 4/50
# Train loss: 0.547077, Validation loss: 0.627499
# ==================================================
# Epoch 5/50
# Train loss: 0.518738, Validation loss: 0.630876
# ==================================================
# Epoch 6/50
# Train loss: 0.503532, Validation loss: 0.633575
# ==================================================
# Epoch 7/50
# Train loss: 0.496240, Validation loss: 0.634908
# ==================================================
# Epoch 8/50
# Train loss: 0.490922, Validation loss: 0.631623
# ==================================================
# Epoch 9/50
# Train loss: 0.486604, Validation loss: 0.630693
# Early stopping triggered after 9 epochs
# Training completed!

# %% [markdown]
# # Evaluating model

# %%
# evaluator = Evaluation(recommender=model, test_data=df_test)
# metrics = evaluator.evaluate(user_batch_size=128, item_batch_size=1024)

# %%
# metrics

# %%
user_count = df_train.groupby('user_id').count()

# %%
user_count[user_count['rating_imp'] == 10].index
# Out:
# Index([    17,    229,    257,    443,    488,    490,    686,    853,   1524,
#          1789,
#        ...
#        591209, 592231, 595300, 606815, 648957, 650130, 657774, 658095, 664050,
#        671908],
#       dtype='int64', name='user_id', length=410)

# %%
df_train[df_train['user_id'] == 17][['item_id', 'name', 'publishers', 'genres', 'categories', 'tags']]
# Out:
#     item_id                                       name  \
# 45    48937                                  Fallout 4
# 46    10791                       GUILTY GEAR -STRIVE-
# 47    40162                                 Quake Live
# 48    38973                                      Depth
# 49     6525  Grand Theft Auto IV: The Complete Edition
# 50    33116             METAL GEAR RISING: REVENGEANCE
# 51    14912                            Forza Horizon 5
# 52        0                             Counter-Strike
# 53    65488                                    Valheim
# 54    51431        S.T.A.L.K.E.R.: Shadow of Chernobyl
#
#                      publishers  \
# 45       ['Bethesda Softworks']
# 46         ['Arc System Works']
# 47       ['Bethesda Softworks']
# 48    ['Digital Confectioners']
# 49           ['Rockstar Games']
# 50                   ['KONAMI']
# 51        ['Xbox Game Studios']
# 52                    ['Valve']
# 53  ['Coffee Stain Publishing']
# 54           ['GSC Game World']
#
#                                                genres  \
# 45                                            ['RPG']
# 46                                         ['Action']
# 47                                         ['Action']
# 48                                ['Action', 'Indie']
# 49                            ['Action', 'Adventure']
# 50                                         ['Action']
# 51  ['Action', 'Adventure', 'Racing', 'Simulation'...
# 52                                         ['Action']
# 53  ['Action', 'Adventure', 'Indie', 'RPG', 'Early...
# 54                                  ['Action', 'RPG']
#
#                                            categories  \
# 45  ['Single-player', 'Steam Achievements', 'Full ...
# 46  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 47  ['Single-player', 'Multi-player', 'Steam Achie...
# 48  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 49  ['Single-player', 'Multi-player', 'Partial Con...
# 50  ['Single-player', 'Steam Achievements', 'Full ...
# 51  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 52  ['Multi-player', 'PvP', 'Online PvP', 'Shared/...
# 53  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 54  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                                  tags
# 45  ['Open World', 'Post-apocalyptic', 'Singleplay...
# 46  ['Fighting', '2D Fighter', 'Great Soundtrack',...
# 47  ['FPS', 'Arena Shooter', 'Multiplayer', 'Class...
# 48  ['Shooter', 'Multiplayer', 'Underwater', 'Atmo...
# 49  ['Open World', 'Action', 'Automobile Sim', 'Cr...
# 50  ['Great Soundtrack', 'Hack and Slash', 'Action...
# 51  ['Racing', 'Open World', 'Driving', 'Multiplay...
# 52  ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...
# 53  ['Open World Survival Craft', 'Survival', 'Onl...
# 54  ['Atmospheric', 'Post-apocalyptic', 'Open Worl...

# %%
df_features = pd.read_csv('../data/metadata-clean.csv')

# %%
actual_items = df_train[df_train['user_id'] == 17]['item_id'].values
actual_items = [index_manager.get_id('item_id', idx) for idx in actual_items]

# %%
actual_items = df_features[df_features['item_id'].isin(actual_items)][['item_id', 'name', 'publishers', 'genres', 'categories', 'tags']]
actual_items
# Out:
#        item_id                                       name  \
# 73619     4500        S.T.A.L.K.E.R.: Shadow of Chernobyl
# 73634       10                             Counter-Strike
# 73657   377160                                  Fallout 4
# 73899   235460             METAL GEAR RISING: REVENGEANCE
# 74142   274940                                      Depth
# 74379   282440                                 Quake Live
# 75737    12210  Grand Theft Auto IV: The Complete Edition
# 78176  1551360                            Forza Horizon 5
# 81509   892970                                    Valheim
# 88091  1384160                       GUILTY GEAR -STRIVE-
#
#                         publishers  \
# 73619           ['GSC Game World']
# 73634                    ['Valve']
# 73657       ['Bethesda Softworks']
# 73899                   ['KONAMI']
# 74142    ['Digital Confectioners']
# 74379       ['Bethesda Softworks']
# 75737           ['Rockstar Games']
# 78176        ['Xbox Game Studios']
# 81509  ['Coffee Stain Publishing']
# 88091         ['Arc System Works']
#
#                                                   genres  \
# 73619                                  ['Action', 'RPG']
# 73634                                         ['Action']
# 73657                                            ['RPG']
# 73899                                         ['Action']
# 74142                                ['Action', 'Indie']
# 74379                                         ['Action']
# 75737                            ['Action', 'Adventure']
# 78176  ['Action', 'Adventure', 'Racing', 'Simulation'...
# 81509  ['Action', 'Adventure', 'Indie', 'RPG', 'Early...
# 88091                                         ['Action']
#
#                                               categories  \
# 73619  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 73634  ['Multi-player', 'PvP', 'Online PvP', 'Shared/...
# 73657  ['Single-player', 'Steam Achievements', 'Full ...
# 73899  ['Single-player', 'Steam Achievements', 'Full ...
# 74142  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 74379  ['Single-player', 'Multi-player', 'Steam Achie...
# 75737  ['Single-player', 'Multi-player', 'Partial Con...
# 78176  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 81509  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 88091  ['Single-player', 'Multi-player', 'PvP', 'Onli...
#
#                                                     tags
# 73619  ['Atmospheric', 'Post-apocalyptic', 'Open Worl...
# 73634  ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...
# 73657  ['Open World', 'Post-apocalyptic', 'Singleplay...
# 73899  ['Great Soundtrack', 'Hack and Slash', 'Action...
# 74142  ['Shooter', 'Multiplayer', 'Underwater', 'Atmo...
# 74379  ['FPS', 'Arena Shooter', 'Multiplayer', 'Class...
# 75737  ['Open World', 'Action', 'Automobile Sim', 'Cr...
# 78176  ['Racing', 'Open World', 'Driving', 'Multiplay...
# 81509  ['Open World Survival Craft', 'Survival', 'Onl...
# 88091  ['Fighting', '2D Fighter', 'Great Soundtrack',...

# %%
recommended_items = model.batch_predict_for_users([17])[17]
recommended_items = [index_manager.get_id('item_id', idx) for idx in recommended_items]
# Out:
# Processing 1 of 1 users... (0.00%)
# Memory usage: 0.681884765625
# Increased user batch size from 128 to 141
# Increased item batch size from 1024 to 1126

# %%
recommended_items = df_features[df_features['item_id'].isin(recommended_items)][['item_id', 'name', 'publishers', 'genres', 'categories', 'tags']]
recommended_items
# Out:
#        item_id                                         name  \
# 3938   1508620                         AV Company | AV会社大冒险
# 5329    986990                              aMAZE Christmas
# 6128    963960            NEONARCADE: adventure puzzle muse
# 14206   749990                                 Trigonometry
# 23403  1966720                               Lethal Company
# 29332   523810                           Wonder Boy Returns
# 29485   519870                                 Flying Pengy
# 37956   435140                        Rush for gold: Alaska
# 40686   346210                                Garden Rescue
# 42341   282010                         Carmageddon Max Pack
# 42560   269010                                Science Girls
# 44057  1229490                                    ULTRAKILL
# 62215  1161930                東方幻夢箋 ~ Touhou Phantasm Dream
# 67809  1044770                         Goddess of Math 数学女神
# 73151   413150                               Stardew Valley
# 73647   105600                                     Terraria
# 75438   227300                       Euro Truck Simulator 2
# 75736  1174180                        Red Dead Redemption 2
# 76080   960090                                  Bloons TD 6
# 76553  1245620                                   ELDEN RING
# 76767   427520                                     Factorio
# 77066   271590                           Grand Theft Auto V
# 77230      620                                     Portal 2
# 77764  1118200                            People Playground
# 77885  2475490                                 Mouthwashing
# 80219   264710                                   Subnautica
# 80562  1533390                                  Gorilla Tag
# 80568  2215430             Ghost of Tsushima DIRECTOR'S CUT
# 81065  1086940                              Baldur's Gate 3
# 81415   489830  The Elder Scrolls V: Skyrim Special Edition
# 81481  2527500                                       MiSide
# 81484   367520                                Hollow Knight
# 81994   553850                                HELLDIVERS™ 2
# 82014  2384580                    DYNASTY WARRIORS: ORIGINS
# 82074  2634950                           Tokyo Xtreme Racer
# 82086   739630                                 Phasmophobia
# 82322   548430                           Deep Rock Galactic
# 82476  1091500                               Cyberpunk 2077
# 82557  2725260            ENDER MAGNOLIA: Bloom in the Mist
# 82835   431960                             Wallpaper Engine
# 83037     4000                                  Garry's Mod
# 83085      220                                  Half-Life 2
# 83249   526870                                 Satisfactory
# 83320   284160                                 BeamNG.drive
# 83459   108600                              Project Zomboid
# 83546  3108510                                    FlyKnight
# 83608  3146520                                   WEBFISHING
# 83665  1366800                                  Crosshair X
# 83734  1623730                                     Palworld
# 84776  1809540                                    Nine Sols
#
#                                               publishers  \
# 3938                               ['Big Breast Studio']
# 5329                                   ['Blender Games']
# 6128                             ['Nozhin games studio']
# 14206                                ['XiNFiNiTY Games']
# 23403                                       ['Zeekerss']
# 29332                                  ['CFK Co., Ltd.']
# 29485                                  ['Bogemic Games']
# 37956                                  ['Rainbow Games']
# 40686                                  ['Rainbow Games']
# 42341                                     ['THQ Nordic']
# 42560                                   ['Hanako Games']
# 44057                          ['New Blood Interactive']
# 62215                                  ['Lonhong Media']
# 67809                                      ['KatusGame']
# 73151                                   ['ConcernedApe']
# 73647                                       ['Re-Logic']
# 75438                                   ['SCS Software']
# 75736                                 ['Rockstar Games']
# 76080                                     ['Ninja Kiwi']
# 76553  ['FromSoftware, Inc.', 'Bandai Namco Entertain...
# 76767                             ['Wube Software LTD.']
# 77066                                 ['Rockstar Games']
# 77230                                          ['Valve']
# 77764                                   ['Studio Minus']
# 77885                                ['CRITICAL REFLEX']
# 80219                   ['Unknown Worlds Entertainment']
# 80562                             ['Another Axiom Inc.']
# 80568                     ['PlayStation Publishing LLC']
# 81065                                 ['Larian Studios']
# 81415                             ['Bethesda Softworks']
# 81481                   ['IndieArk', 'Shochiku (Japan)']
# 81484                                    ['Team Cherry']
# 81994                     ['PlayStation Publishing LLC']
# 82014                     ['KOEI TECMO GAMES CO., LTD.']
# 82074                                 ['Genki Co.,Ltd.']
# 82086                                  ['Kinetic Games']
# 82322                        ['Coffee Stain Publishing']
# 82476                                 ['CD PROJEKT RED']
# 82557                        ['Binary Haze Interactive']
# 82835                          ['Wallpaper Engine Team']
# 83037                                          ['Valve']
# 83085                                          ['Valve']
# 83249                        ['Coffee Stain Publishing']
# 83320                                         ['BeamNG']
# 83459                                ['The Indie Stone']
# 83546                                       ['Wabbaboy']
# 83608                                  ['lamedeveloper']
# 83665                             ['CenterPoint Gaming']
# 83734                                     ['Pocketpair']
# 84776                                 ['RedCandleGames']
#
#                                                   genres  \
# 3938   ['Action', 'Adventure', 'Casual', 'Indie', 'RP...
# 5329   ['Adventure', 'Casual', 'Indie', 'Simulation',...
# 6128                    ['Adventure', 'Casual', 'Indie']
# 14206                      ['Action', 'Casual', 'Indie']
# 23403   ['Action', 'Adventure', 'Indie', 'Early Access']
# 29332                               ['Action', 'Casual']
# 29485                                ['Casual', 'Indie']
# 37956                             ['Casual', 'Strategy']
# 40686                             ['Casual', 'Strategy']
# 42341                      ['Action', 'Indie', 'Racing']
# 42560                                   ['Indie', 'RPG']
# 44057                ['Action', 'Indie', 'Early Access']
# 62215            ['Adventure', 'Casual', 'Indie', 'RPG']
# 67809          ['Action', 'Casual', 'Indie', 'Strategy']
# 73151                     ['Indie', 'RPG', 'Simulation']
# 73647            ['Action', 'Adventure', 'Indie', 'RPG']
# 75438                            ['Indie', 'Simulation']
# 75736                            ['Action', 'Adventure']
# 76080                                       ['Strategy']
# 76553                                  ['Action', 'RPG']
# 76767      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 77066                            ['Action', 'Adventure']
# 77230                            ['Action', 'Adventure']
# 77764        ['Action', 'Casual', 'Indie', 'Simulation']
# 77885                             ['Adventure', 'Indie']
# 80219                             ['Adventure', 'Indie']
# 80562                               ['Action', 'Casual']
# 80568                            ['Action', 'Adventure']
# 81065                   ['Adventure', 'RPG', 'Strategy']
# 81415                                            ['RPG']
# 81481        ['Adventure', 'Indie', 'RPG', 'Simulation']
# 81484                   ['Action', 'Adventure', 'Indie']
# 81994                                         ['Action']
# 82014                      ['Action', 'RPG', 'Strategy']
# 82074                         ['Racing', 'Early Access']
# 82086                ['Action', 'Indie', 'Early Access']
# 82322                                         ['Action']
# 82476                                            ['RPG']
# 82557                                  ['Action', 'RPG']
# 82835  ['Casual', 'Indie', 'Animation & Modeling', 'D...
# 83037                  ['Casual', 'Indie', 'Simulation']
# 83085                                         ['Action']
# 83249   ['Adventure', 'Indie', 'Simulation', 'Strategy']
# 83320           ['Racing', 'Simulation', 'Early Access']
# 83459     ['Indie', 'RPG', 'Simulation', 'Early Access']
# 83546                     ['Action', 'Adventure', 'RPG']
# 83608       ['Casual', 'Indie', 'Massively Multiplayer']
# 83665  ['Action', 'Adventure', 'Indie', 'Animation & ...
# 83734  ['Action', 'Adventure', 'Indie', 'RPG', 'Early...
# 84776                   ['Action', 'Adventure', 'Indie']
#
#                                               categories  \
# 3938   ['Single-player', 'Steam Cloud', 'Family Shari...
# 5329   ['Single-player', 'Steam Achievements', 'Steam...
# 6128   ['Single-player', 'Steam Achievements', 'Famil...
# 14206  ['Single-player', 'Steam Achievements', 'Full ...
# 23403  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 29332  ['Single-player', 'Steam Achievements', 'Full ...
# 29485  ['Single-player', 'Steam Achievements', 'Full ...
# 37956  ['Single-player', 'Steam Trading Cards', 'Fami...
# 40686  ['Single-player', 'Steam Trading Cards', 'Fami...
# 42341  ['Single-player', 'Multi-player', 'Steam Tradi...
# 42560  ['Single-player', 'Steam Achievements', 'Famil...
# 44057  ['Single-player', 'Full controller support', '...
# 62215  ['Single-player', 'Partial Controller Support'...
# 67809                                  ['Single-player']
# 73151  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 73647  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 75438  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 75736  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 76080  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 76553  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 76767  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 77066  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 77230  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 77764  ['Single-player', 'Steam Achievements', 'Steam...
# 77885  ['Single-player', 'Steam Achievements', 'Full ...
# 80219  ['Single-player', 'Steam Achievements', 'Full ...
# 80562  ['Multi-player', 'PvP', 'Online PvP', 'Cross-P...
# 80568  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 81065  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 81415  ['Single-player', 'Steam Achievements', 'Parti...
# 81481  ['Single-player', 'Steam Achievements', 'Famil...
# 81484  ['Single-player', 'Steam Achievements', 'Full ...
# 81994  ['Multi-player', 'Co-op', 'Online Co-op', 'Ste...
# 82014  ['Single-player', 'Steam Achievements', 'Full ...
# 82074  ['Single-player', 'Full controller support', '...
# 82086  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 82322  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 82476  ['Single-player', 'Steam Achievements', 'Full ...
# 82557  ['Single-player', 'Steam Achievements', 'Full ...
# 82835  ['Steam Achievements', 'Steam Trading Cards', ...
# 83037  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 83085  ['Single-player', 'Steam Achievements', 'Full ...
# 83249  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 83320  ['Single-player', 'Steam Achievements', 'Steam...
# 83459  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 83546  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 83608  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 83665  ['Captions available', 'Steam Workshop', 'Part...
# 83734  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 84776  ['Single-player', 'Steam Achievements', 'Full ...
#
#                                                     tags
# 3938                                                  []
# 5329   ['Strategy', 'Singleplayer', 'Puzzle', 'Fast-P...
# 6128                    ['Adventure', 'Indie', 'Casual']
# 14206  ['Indie', 'Casual', 'Action', 'Singleplayer', ...
# 23403  ['Online Co-Op', 'Horror', 'First-Person', 'Co...
# 29332  ['Casual', 'Action', 'Platformer', 'Classic', ...
# 29485  ['Casual', 'Indie', 'Arcade', 'Funny', 'Old Sc...
# 37956          ['Strategy', 'Casual', 'Time Management']
# 40686            ['Strategy', 'Casual', 'Tower Defense']
# 42341  ['Combat Racing', 'Racing', 'Gore', 'Action', ...
# 42560  ['JRPG', 'Female Protagonist', 'Science', 'Ani...
# 44057  ['Boomer Shooter', 'Fast-Paced', 'FPS', 'Blood...
# 62215  ['RPG', 'Adventure', 'Indie', 'Casual', 'Bulle...
# 67809  ['Indie', 'Action', 'Casual', 'Strategy', 'Edu...
# 73151  ['Farming Sim', 'Pixel Graphics', 'Multiplayer...
# 73647  ['Open World Survival Craft', 'Sandbox', 'Surv...
# 75438  ['Driving', 'Transportation', 'Simulation', 'O...
# 75736  ['Open World', 'Story Rich', 'Western', 'Adven...
# 76080  ['Tower Defense', 'Strategy', 'Multiplayer', '...
# 76553  ['Souls-like', 'Open World', 'Dark Fantasy', '...
# 76767  ['Automation', 'Base-Building', 'Resource Mana...
# 77066  ['Open World', 'Action', 'Multiplayer', 'Crime...
# 77230  ['Platformer', 'Puzzle', 'First-Person', 'Dark...
# 77764  ['Sandbox', 'Gore', 'Physics', 'Blood', 'Modda...
# 77885  ['Psychological Horror', 'Story Rich', 'Horror...
# 80219  ['Open World Survival Craft', 'Survival', 'Hor...
# 80562  ['VR', 'Psychological Horror', 'Multiplayer', ...
# 80568  ['Action', 'Open World', 'Singleplayer', 'Stor...
# 81065  ['RPG', 'Character Customization', 'Choices Ma...
# 81415  ['Open World', 'RPG', 'Adventure', 'Singleplay...
# 81481  ['Psychological Horror', 'Cute', 'Story Rich',...
# 81484  ['Metroidvania', 'Souls-like', 'Platformer', '...
# 81994  ['Online Co-Op', 'PvE', 'Third-Person Shooter'...
# 82014  ['Hack and Slash', 'Spectacle fighter', 'Warga...
# 82074  ['Racing', 'Driving', 'Controller', '3D', 'Aut...
# 82086  ['Horror', 'Online Co-Op', 'Multiplayer', 'Psy...
# 82322  ['Dwarf', 'Co-op', 'PvE', 'FPS', 'Procedural G...
# 82476  ['Cyberpunk', 'Open World', 'Nudity', 'RPG', '...
# 82557  ['Metroidvania', '2D', 'Dark Fantasy', 'Single...
# 82835  ['Mature', 'Utilities', 'Anime', 'Software', '...
# 83037  ['Sandbox', 'Moddable', 'Multiplayer', 'Physic...
# 83085  ['FPS', 'Action', 'Sci-fi', 'Classic', 'Single...
# 83249  ['Base-Building', 'Automation', 'Open World', ...
# 83320  ['Simulation', 'Driving', 'Physics', 'Realisti...
# 83459  ['Survival', 'Zombies', 'Open World', 'Multipl...
# 83546  ['Dungeon Crawler', 'First-Person', 'Souls-lik...
# 83608  ['Fishing', 'Multiplayer', 'Casual', 'Cute', '...
# 83665  ['Action', 'Indie', 'Adventure', 'Utilities', ...
# 83734  ['Open World', 'Survival', 'Creature Collector...
# 84776  ['Metroidvania', 'Souls-like', 'Difficult', 'A...

# %%
import ast
recommended_items['tags'] = recommended_items['tags'].apply(lambda x: ast.literal_eval(x))
recommended_items['categories'] = recommended_items['categories'].apply(lambda x: ast.literal_eval(x))
recommended_items['genres'] = recommended_items['genres'].apply(lambda x: ast.literal_eval(x))

# %%
recommended_tags = recommended_items.explode('tags')['tags'].unique()
recommended_categories = recommended_items.explode('categories')['categories'].unique()
recommended_genres = recommended_items.explode('genres')['genres'].unique()

# %%
import ast
actual_items['tags'] = actual_items['tags'].apply(lambda x: ast.literal_eval(x))
actual_items['categories'] = actual_items['categories'].apply(lambda x: ast.literal_eval(x))
actual_items['genres'] = actual_items['genres'].apply(lambda x: ast.literal_eval(x))

# %%
actual_tags = actual_items.explode('tags')['tags'].unique()
actual_categories = actual_items.explode('categories')['categories'].unique()
actual_genres = actual_items.explode('genres')['genres'].unique()

# %%
shared_tags = set(recommended_tags).intersection(actual_tags)
len(shared_tags)/len(actual_tags)
# Out:
# 0.7878787878787878

# %%
shared_categories = set(recommended_categories).intersection(actual_categories)
len(shared_categories)/len(actual_categories)
# Out:
# 0.9642857142857143

# %%
shared_genres = set(recommended_genres).intersection(actual_genres)
len(shared_genres)/len(actual_genres)
# Out:
# 0.875
